# %%
import pandas as pd
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))
from src.preprocess import preprocess_data

# %%
df = pd.read_csv("../data/raw/Nepali_house_dataset.csv")

# %%
df_clean = preprocess_data(df)
# Out:
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["LOCATION"] = (
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["LOCATION"] = df["LOCATION"].replace({
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:107: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["LAND_AREA"] = df["LAND AREA"].apply(convert_to_sqft)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:109: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ROAD_ACCESS"] = df["ROAD ACCESS"].apply(process_road_access)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["FACING"] = df["FACING"].str.lower().str.strip()
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["FACING"] = df["FACING"].replace({
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:113: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["BUILT_YEAR"] = df["BUILT YEAR"].str.extract(r"(\d+)").astype(float)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:115: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["AMENITY_COUNT"] = df["AMENITIES"].apply(lambda x: len(ast.literal_eval(x)) if pd.notna(x) else 0)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["AMENITIES"] = df["AMENITIES"].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else [])
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"has_{amenity.lower().replace(' ', '_')}"] = df["AMENITIES"].apply(lambda x: amenity in x)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"has_{amenity.lower().replace(' ', '_')}"] = df["AMENITIES"].apply(lambda x: amenity in x)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"has_{amenity.lower().replace(' ', '_')}"] = df["AMENITIES"].apply(lambda x: amenity in x)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"has_{amenity.lower().replace(' ', '_')}"] = df["AMENITIES"].apply(lambda x: amenity in x)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"has_{amenity.lower().replace(' ', '_')}"] = df["AMENITIES"].apply(lambda x: amenity in x)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"has_{amenity.lower().replace(' ', '_')}"] = df["AMENITIES"].apply(lambda x: amenity in x)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"has_{amenity.lower().replace(' ', '_')}"] = df["AMENITIES"].apply(lambda x: amenity in x)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"has_{amenity.lower().replace(' ', '_')}"] = df["AMENITIES"].apply(lambda x: amenity in x)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"has_{amenity.lower().replace(' ', '_')}"] = df["AMENITIES"].apply(lambda x: amenity in x)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:126: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(["BUILDUP AREA","LAND AREA","ROAD ACCESS","BUILT YEAR","PARKING","AMENITIES"], axis=1, inplace=True)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:128: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["LAND_AREA"].fillna(df["LAND_AREA"].median(), inplace=True)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["LAND_AREA"].fillna(df["LAND_AREA"].median(), inplace=True)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:130: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["ROAD_ACCESS"].fillna(df["ROAD_ACCESS"].median(), inplace=True)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ROAD_ACCESS"].fillna(df["ROAD_ACCESS"].median(), inplace=True)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:132: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["FACING"].fillna(df["FACING"].mode()[0], inplace=True)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["FACING"].fillna(df["FACING"].mode()[0], inplace=True)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:134: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["FLOOR"].fillna(df["FLOOR"].median(), inplace=True)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:134: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["FLOOR"].fillna(df["FLOOR"].median(), inplace=True)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:135: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["BEDROOM"].fillna(df["BEDROOM"].median(), inplace=True)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:135: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["BEDROOM"].fillna(df["BEDROOM"].median(), inplace=True)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:136: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["BATHROOM"].fillna(df["BATHROOM"].median(), inplace=True)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:136: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["BATHROOM"].fillna(df["BATHROOM"].median(), inplace=True)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:137: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["BUILT_YEAR"].fillna(df["BUILT_YEAR"].median(), inplace=True)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:137: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["BUILT_YEAR"].fillna(df["BUILT_YEAR"].median(), inplace=True)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["house_age"] = current_year - df["BUILT_YEAR"]
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop("BUILT_YEAR",axis=1,inplace=True)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:142: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["bath_per_bed"] = np.where(
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:147: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["bath_per_bed"].fillna(df["bath_per_bed"].median(), inplace=True)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["bath_per_bed"].fillna(df["bath_per_bed"].median(), inplace=True)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["area_road_interaction"] = df["LAND_AREA"] * df["ROAD_ACCESS"]
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:149: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["area_bedroom"] = df["LAND_AREA"] * df["BEDROOM"]

# %%
df_clean.head()
# Out:
#     LOCATION       PRICE      FACING  FLOOR  BEDROOM  BATHROOM  LAND_AREA  \
# 0   Lalitpur  29000000.0        west    3.0      5.0       4.0    125.440
# 1   Lalitpur  47500000.0        west    4.5      5.0       6.0     94.080
# 2   Lalitpur  19900000.0        west    2.5      4.0       4.0     72.128
# 3   Lalitpur  40000000.0  north-west    2.5      4.0       3.0    219.520
# 4  Kathmandu  12000000.0       south    2.0      4.0       4.0    188.160
#
#    ROAD_ACCESS  AMENITY_COUNT  has_drainage  ...  has_marbel  \
# 0         12.0             11         False  ...        True
# 1         10.0             11         False  ...       False
# 2         10.0             11         False  ...        True
# 3         12.0             11         False  ...        True
# 4         20.0             11         False  ...       False
#
#    has_power_backup  has_earthquake_resistant  has_garden  has_parquet  \
# 0             False                      True       False         True
# 1             False                      True       False         True
# 2             False                      True       False         True
# 3             False                      True        True         True
# 4             False                      True       False         True
#
#    has_modular_kitchen  house_age  bath_per_bed  area_road_interaction  \
# 0                 True        6.0          0.80                1505.28
# 1                 True        6.0          1.20                 940.80
# 2                 True       22.0          1.00                 721.28
# 3                 True       23.0          0.75                2634.24
# 4                 True       11.0          1.00                3763.20
#
#    area_bedroom
# 0       627.200
# 1       470.400
# 2       288.512
# 3       878.080
# 4       752.640
#
# [5 rows x 22 columns]

# %%
df_clean.isna().sum()
# Out:
# LOCATION                    0
# PRICE                       0
# FACING                      0
# FLOOR                       0
# BEDROOM                     0
# BATHROOM                    0
# LAND_AREA                   0
# ROAD_ACCESS                 0
# AMENITY_COUNT               0
# has_drainage                0
# has_parking                 0
# has_drinking_water          0
# has_marbel                  0
# has_power_backup            0
# has_earthquake_resistant    0
# has_garden                  0
# has_parquet                 0
# has_modular_kitchen         0
# house_age                   0
# bath_per_bed                0
# area_road_interaction       0
# area_bedroom                0
# dtype: int64

# %%
df_clean.to_csv("../data/processed/clean_housing.csv", index=False)
