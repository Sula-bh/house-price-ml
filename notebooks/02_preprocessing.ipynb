# %%
import pandas as pd
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))
from src.preprocess import preprocess_data

# %%
df = pd.read_csv("../data/raw/Nepali_house_dataset.csv")

# %%
df_clean = preprocess_data(df)
# Out:
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["LOCATION"] = df["LOCATION"].apply(
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["LAND_AREA"] = df["LAND AREA"].apply(convert_to_sqft)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ROAD_ACCESS"] = df["ROAD ACCESS"].apply(process_road_access)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["FACING"] = df["FACING"].str.lower().str.strip()
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["FACING"] = df["FACING"].replace({
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["BUILT_YEAR"] = df["BUILT YEAR"].str.extract(r"(\d+)").astype(float)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:95: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["AMENITY_COUNT"] = df["AMENITIES"].apply(lambda x: len(ast.literal_eval(x)) if pd.notna(x) else 0)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["AMENITIES"] = df["AMENITIES"].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else [])
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:103: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"has_{amenity.lower().replace(' ', '_')}"] = df["AMENITIES"].apply(lambda x: amenity in x)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:103: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"has_{amenity.lower().replace(' ', '_')}"] = df["AMENITIES"].apply(lambda x: amenity in x)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:103: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"has_{amenity.lower().replace(' ', '_')}"] = df["AMENITIES"].apply(lambda x: amenity in x)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:103: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"has_{amenity.lower().replace(' ', '_')}"] = df["AMENITIES"].apply(lambda x: amenity in x)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:103: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"has_{amenity.lower().replace(' ', '_')}"] = df["AMENITIES"].apply(lambda x: amenity in x)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:103: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"has_{amenity.lower().replace(' ', '_')}"] = df["AMENITIES"].apply(lambda x: amenity in x)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:103: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"has_{amenity.lower().replace(' ', '_')}"] = df["AMENITIES"].apply(lambda x: amenity in x)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:103: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"has_{amenity.lower().replace(' ', '_')}"] = df["AMENITIES"].apply(lambda x: amenity in x)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:103: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"has_{amenity.lower().replace(' ', '_')}"] = df["AMENITIES"].apply(lambda x: amenity in x)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:103: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"has_{amenity.lower().replace(' ', '_')}"] = df["AMENITIES"].apply(lambda x: amenity in x)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(["BUILDUP AREA","LAND AREA","ROAD ACCESS","BUILT YEAR","PARKING","AMENITIES"], axis=1, inplace=True)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:107: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["LAND_AREA"].fillna(df["LAND_AREA"].median(), inplace=True)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:107: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["LAND_AREA"].fillna(df["LAND_AREA"].median(), inplace=True)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:109: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["ROAD_ACCESS"].fillna(df["ROAD_ACCESS"].median(), inplace=True)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:109: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ROAD_ACCESS"].fillna(df["ROAD_ACCESS"].median(), inplace=True)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:111: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["FACING"].fillna(df["FACING"].mode()[0], inplace=True)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["FACING"].fillna(df["FACING"].mode()[0], inplace=True)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:113: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["FLOOR"].fillna(df["FLOOR"].median(), inplace=True)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:113: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["FLOOR"].fillna(df["FLOOR"].median(), inplace=True)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:114: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["BEDROOM"].fillna(df["BEDROOM"].median(), inplace=True)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:114: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["BEDROOM"].fillna(df["BEDROOM"].median(), inplace=True)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:115: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["BATHROOM"].fillna(df["BATHROOM"].median(), inplace=True)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:115: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["BATHROOM"].fillna(df["BATHROOM"].median(), inplace=True)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:116: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["BUILT_YEAR"].fillna(df["BUILT_YEAR"].median(), inplace=True)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:116: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["BUILT_YEAR"].fillna(df["BUILT_YEAR"].median(), inplace=True)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:118: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["bedroom_density"] = np.where(
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:123: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["bedroom_density"].fillna(df["bedroom_density"].median(), inplace=True)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:123: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["bedroom_density"].fillna(df["bedroom_density"].median(), inplace=True)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["bath_per_bed"] = np.where(
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:129: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["bath_per_bed"].fillna(df["bath_per_bed"].median(), inplace=True)
# c:\Users\DELL\Downloads\ML Projects\house-price-ml\src\preprocess.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["bath_per_bed"].fillna(df["bath_per_bed"].median(), inplace=True)

# %%
df_clean.head()
# Out:
#                LOCATION       PRICE      FACING  FLOOR  BEDROOM  BATHROOM  \
# 0      Imadol, Lalitpur  29000000.0        west    3.0      5.0       4.0
# 1                 Other  47500000.0        west    4.5      5.0       6.0
# 2      Imadol, Lalitpur  19900000.0        west    2.5      4.0       4.0
# 3  Bhaisepati, Lalitpur  40000000.0  north-west    2.5      4.0       3.0
# 4                 Other  12000000.0       south    2.0      4.0       4.0
#
#    LAND_AREA  ROAD_ACCESS  BUILT_YEAR  AMENITY_COUNT  ...  has_bathroom  \
# 0    125.440         12.0      2076.0             11  ...         False
# 1     94.080         10.0      2076.0             11  ...          True
# 2     72.128         10.0      2060.0             11  ...         False
# 3    219.520         12.0      2059.0             11  ...         False
# 4    188.160         20.0      2071.0             11  ...          True
#
#    has_drinking_water  has_marbel  has_power_backup  has_earthquake_resistant  \
# 0                True        True             False                      True
# 1                True       False             False                      True
# 2                True        True             False                      True
# 3                True        True             False                      True
# 4                True       False             False                      True
#
#    has_garden  has_parquet  has_modular_kitchen  bedroom_density  bath_per_bed
# 0       False         True                 True         0.039860          0.80
# 1       False         True                 True         0.053146          1.20
# 2       False         True                 True         0.055457          1.00
# 3        True         True                 True         0.018222          0.75
# 4       False         True                 True         0.021259          1.00
#
# [5 rows x 22 columns]

# %%
df_clean.isna().sum()
# Out:
# LOCATION                    0
# PRICE                       0
# FACING                      0
# FLOOR                       0
# BEDROOM                     0
# BATHROOM                    0
# LAND_AREA                   0
# ROAD_ACCESS                 0
# BUILT_YEAR                  0
# AMENITY_COUNT               0
# has_drainage                0
# has_parking                 0
# has_bathroom                0
# has_drinking_water          0
# has_marbel                  0
# has_power_backup            0
# has_earthquake_resistant    0
# has_garden                  0
# has_parquet                 0
# has_modular_kitchen         0
# bedroom_density             0
# bath_per_bed                0
# dtype: int64

# %%
df_clean.to_csv("../data/processed/clean_housing.csv", index=False)
